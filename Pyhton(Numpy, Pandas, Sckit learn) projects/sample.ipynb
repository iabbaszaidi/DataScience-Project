# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import os
data_path = r"C:\Users\syeda\WORK\Microsoft VS Code\WORK\python projects\real_estate_price_size.csv"
print("exists:", os.path.exists(data_path))
print("reading:", data_path)
data = pd.read_csv(data_path)
print(data.head())
# Out:
# exists: True
# reading: C:\Users\syeda\WORK\Microsoft VS Code\WORK\python projects\real_estate_price_size.csv
#         price     size
# 0  234314.144   643.09
# 1  228581.528   656.22
# 2  281626.336   487.29
# 3  401255.608  1504.75
# 4  458674.256  1275.46

# %%
data.describe()
# Out:
#                price         size
# count     100.000000   100.000000
# mean   292289.470160   853.024200
# std     77051.727525   297.941951
# min    154282.128000   479.750000
# 25%    234280.148000   643.330000
# 50%    280590.716000   696.405000
# 75%    335723.696000  1029.322500
# max    500681.128000  1842.510000

# %%
y = data['price']
x1 = data['size']

# %%
plt.scatter(y,x1)
plt.xlabel('size', fontsize=15)
plt.ylabel('price', fontsize=15)
plt.show()

# %%
x = sm.add_constant(x1)  # adding a constant
model = sm.OLS(y, x).fit()
results = model.summary()
print(results)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.745
# Model:                            OLS   Adj. R-squared:                  0.742
# Method:                 Least Squares   F-statistic:                     285.9
# Date:                Thu, 08 Jan 2026   Prob (F-statistic):           8.13e-31
# Time:                        15:47:33   Log-Likelihood:                -1198.3
# No. Observations:                 100   AIC:                             2401.
# Df Residuals:                      98   BIC:                             2406.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.019e+05   1.19e+04      8.550      0.000    7.83e+04    1.26e+05
# ...

# %%
plt.scatter(x1,y)
yhat = 223.1787*x1 + 1.019e+05
fig = plt.plot(x1, yhat, lw=4, c='orange', label='regression line')
plt.xlabel('size', fontsize=15)
plt.ylabel('price', fontsize=15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.scatter(x1,y)
#       2 yhat = 223.1787*x1 + 1.019e+05
#       3 fig = plt.plot(x1, yhat, lw=4, c='orange', label='regression line')
#
# NameError: name 'plt' is not defined

# %%
print("hello")
# Out:
# hello

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from sklearn.linear_model import LinearRegression

# %%
# We start by loading the data
data = pd.read_csv(r"C:\Users\syeda\WORK\Microsoft VS Code\WORK\python projects\1.01.+Simple+linear+regression.csv")

# Let's explore the top 5 rows of the df
data.head()
# Out:
#     SAT   GPA
# 0  1714  2.40
# 1  1664  2.52
# 2  1760  2.54
# 3  1685  2.74
# 4  1693  2.83

# %%
# There is a single independent variable: 'SAT'
x = data['SAT']

# and a single depended variable: 'GPA'
y = data['GPA']

# %%
x.shape
y.shape
# Out:
# (84,)

# %%
x_matrix = x.values.reshape(-1,1)
x_matrix.shape
# Out:
# (84, 1)

# %%
reg = LinearRegression()

# %%
reg.fit(x_matrix,y)
# Out:
# LinearRegression()
